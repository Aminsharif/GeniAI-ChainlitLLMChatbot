# %%
from groq import Groq

client = Groq()

chat_completion = client.chat.completions.create(
    #
    # Required parameters
    #
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "you are a helpful assistant."
        },
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],

    # The language model which will generate the completion.
    model="llama3-8b-8192",

    #
    # Optional parameters
    #

    # Controls randomness: lowering results in less random completions.
    # As the temperature approaches zero, the model will become deterministic
    # and repetitive.
    temperature=0.5,

    # The maximum number of tokens to generate. Requests can use up to
    # 2048 tokens shared between prompt and completion.
    max_tokens=1024,

    # Controls diversity via nucleus sampling: 0.5 means half of all
    # likelihood-weighted options are considered.
    top_p=1,

    # A stop sequence is a predefined or user-specified text string that
    # signals an AI to stop generating content, ensuring its responses
    # remain focused and concise. Examples include punctuation marks and
    # markers like "[end]".
    # For this example, we will use ", 6" so that the llm stops counting at 5.
    # If multiple stop values are needed, an array of string may be passed,
    # stop=[", 6", ", six", ", Six"]
    stop=", 6",

    # If set, partial message deltas will be sent.
    stream=False,
)

# Print the completion returned by the LLM.
print(chat_completion.choices[0].message.content)
# Out:
# Fast language models have gained significant attention in recent years due to their ability to process and generate human-like text quickly and efficiently. Here are some reasons why fast language models are important:
#
# 1. **Speed and Efficiency**: Fast language models can process and respond to user queries or tasks much faster than traditional language models. This is particularly important in applications such as chatbots, virtual assistants, and language translation, where speed and responsiveness are crucial.
# 2. **Scalability**: Fast language models can handle large volumes of text data and scale to meet the demands of increasingly complex tasks. This makes them ideal for applications such as text summarization, sentiment analysis, and language translation.
# 3. **Improved User Experience**: Fast language models can provide a more seamless and interactive user experience by quickly responding to user input and generating relevant output. This is particularly important in applications such as customer service, where fast and accurate responses can improve customer satisfaction.
# 4. **Enhanced Decision-Making**: Fast language models can analyze large amounts of text data quickly and provide insights that can inform business decisions. For example, sentiment analysis can help businesses understand customer opinions and preferences.
# 5. **Advancements in AI Research**: Fast language models have enabled researchers to explore new areas of AI research, such as multimodal language processing, where language models are used in conjunction with other modalities such as images and audio.
# 6. **Improved Language Understanding**: Fast language models can be fine-tuned for specific tasks and domains, enabling them to understand language nuances and idioms more accurately. This is particularly important in applications such as language translation and text summarization.
# 7. **Cost-Effectiveness**: Fast language models can be more cost-effective than traditional language models, as they require less computational resources and can be deployed on a wider range of devices.
# 8. **Increased Accessibility**: Fast language models can be used to improve language accessibility for people with disabilities, such as those who rely on screen readers or text-to-speech systems.
# 9. **Enhanced Creativity**: Fast language models can be used to generate creative content, such as poetry, stories, and dialogues, which can be used in various applications such as entertainment, education, and marketing.
# 10. **Future-Proofing**: Fast language models are well-positioned to handle the increasing demands of language processing tasks in the future, as they can be easily scaled and fine-tuned to meet emerging needs.
#
# Overall, fast language models have the potential to revolutionize the way we interact with language and technology, enabling faster, more accurate, and more efficient processing and generation of human language.

# %%
result
# Out:
# ['',
#  'Fast',
#  ' language',
#  ' models',
#  ' have',
#  ' gained',
#  ' significant',
#  ' attention',
#  ' in',
#  ' recent',
#  ' years',
#  ' due',
#  ' to',
#  ' their',
#  ' ability',
#  ' to',
#  ' process',
#  ' and',
#  ' generate',
#  ' human',
#  '-like',
#  ' text',
#  ' quickly',
#  ' and',
#  ' efficiently',
#  '.',
#  ' Here',
#  ' are',
#  ' some',
#  ' reasons',
#  ' why',
#  ' fast',
#  ' language',
#  ' models',
#  ' are',
#  ' important',
#  ':\n\n',
#  '1',
#  '.',
#  ' **',
#  'Real',
#  '-time',
#  ' applications',
#  '**:',
#  ' Fast',
#  ' language',
#  ' models',
#  ' are',
#  ' crucial',
#  ' for',
#  ' real',
#  '-time',
#  ' applications',
#  ' such',
#  ' as',
#  ' chat',
#  'bots',
#  ',',
#  ' virtual',
#  ' assistants',
#  ',',
#  ' and',
#  ' language',
#  ' translation',
#  ' services',
#  '.',
#  ' They',
#  ' enable',
#  ' these',
#  ' systems',
#  ' to',
#  ' respond',
#  ' quickly',
#  ' to',
#  ' user',
#  ' inputs',
#  ',',
#  ' making',
#  ' interactions',
#  ' more',
#  ' seamless',
#  ' and',
#  ' user',
#  '-friendly',
#  '.\n',
#  '2',
#  '.',
#  ' **',
#  'Sc',
#  'al',
#  'ability',
#  '**:',
#  ' As',
#  ' the',
#  ' amount',
#  ' of',
#  ' data',
#  ' and',
#  ' user',
#  ' interactions',
#  ' increase',
#  ',',
#  ' fast',
#  ' language',
#  ' models',
#  ' can',
#  ' handle',
#  ' the',
#  ' load',
#  ' more',
#  ' efficiently',
#  ',',
#  ' ensuring',
#  ' that',
#  ' systems',
#  ' remain',
#  ' responsive',
#  ' and',
#  ' scalable',
#  '.\n',
#  '3',
#  '.',
#  ' **',
#  'Improved',
#  ' user',
#  ' experience',
#  '**:',
#  ' By',
#  ' generating',
#  ' text',
#  ' quickly',
#  ',',
#  ' fast',
#  ' language',
#  ' models',
#  ' can',
#  ' reduce',
#  ' the',
#  ' time',
#  ' it',
#  ' takes',
#  ' for',
#  ' users',
#  ' to',
#  ' get',
#  ' the',
#  ' information',
#  ' they',
#  ' need',
#  ',',
#  ' making',
#  ' the',
#  ' overall',
#  ' user',
#  ' experience',
#  ' faster',
#  ' and',
#  ' more',
#  ' convenient',
#  '.\n',
#  '4',
#  '.',
#  ' **',
#  'Enh',
#  'anced',
#  ' decision',
#  '-making',
#  '**:',
#  ' In',
#  ' applications',
#  ' like',
#  ' natural',
#  ' language',
#  ' processing',
#  ' (',
#  'N',
#  'LP',
#  ')',
#  ' and',
#  ' machine',
#  ' learning',
#  ',',
#  ' fast',
#  ' language',
#  ' models',
#  ' can',
#  ' process',
#  ' and',
#  ' analyze',
#  ' large',
#  ' amounts',
#  ' of',
#  ' text',
#  ' data',
#  ' quickly',
#  ',',
#  ' enabling',
#  ' faster',
#  ' decision',
#  '-making',
#  ' and',
#  ' improved',
#  ' insights',
#  '.\n',
#  '5',
#  '.',
#  ' **',
#  'Cost',
#  '-effective',
#  '**:',
#  ' Fast',
#  ' language',
#  ' models',
#  ' can',
#  ' reduce',
#  ' the',
#  ' computational',
#  ' resources',
#  ' required',
#  ' for',
#  ' text',
#  ' processing',
#  ',',
#  ' making',
#  ' them',
#  ' a',
#  ' cost',
#  '-effective',
#  ' solution',
#  ' for',
#  ' organizations',
#  ' and',
#  ' individuals',
#  '.\n',
#  '6',
#  '.',
#  ' **',
#  'Adv',
#  'ancements',
#  ' in',
#  ' AI',
#  '**:',
#  ' Fast',
#  ' language',
#  ' models',
#  ' are',
#  ' a',
#  ' key',
#  ' component',
#  ' in',
#  ' the',
#  ' development',
#  ' of',
#  ' artificial',
#  ' intelligence',
#  ' (',
#  'AI',
#  ')',
#  ' and',
#  ' natural',
#  ' language',
#  ' processing',
#  ' (',
#  'N',
#  'LP',
#  ')',
#  ' technologies',
#  ',',
#  ' enabling',
#  ' advancements',
#  ' in',
#  ' areas',
#  ' like',
#  ' language',
#  ' translation',
#  ',',
#  ' sentiment',
#  ' analysis',
#  ',',
#  ' and',
#  ' text',
#  ' summar',
#  'ization',
#  '.\n',
#  '7',
#  '.',
#  ' **',
#  'Improved',
#  ' accuracy',
#  '**:',
#  ' By',
#  ' processing',
#  ' text',
#  ' quickly',
#  ',',
#  ' fast',
#  ' language',
#  ' models',
#  ' can',
#  ' also',
#  ' improve',
#  ' the',
#  ' accuracy',
#  ' of',
#  ' text',
#  ' analysis',
#  ' and',
#  ' generation',
#  ' tasks',
#  ',',
#  ' as',
#  ' they',
#  ' can',
#  ' handle',
#  ' complex',
#  ' linguistic',
#  ' structures',
#  ' and',
#  ' nuances',
#  ' more',
#  ' efficiently',
#  '.\n',
#  '8',
#  '.',
#  ' **',
#  'Real',
#  '-time',
#  ' feedback',
#  '**:',
#  ' Fast',
#  ' language',
#  ' models',
#  ' can',
#  ' provide',
#  ' real',
#  '-time',
#  ' feedback',
#  ' and',
#  ' suggestions',
#  ',',
#  ' enabling',
#  ' users',
#  ' to',
#  ' refine',
#  ' their',
#  ' queries',
#  ' and',
#  ' improve',
#  ' the',
#  ' accuracy',
#  ' of',
#  ' their',
#  ' searches',
#  '.\n',
#  '9',
#  '.',
#  ' **',
#  'Enh',
#  'anced',
#  ' customer',
#  ' service',
#  '**:',
#  ' By',
#  ' responding',
#  ' quickly',
#  ' to',
#  ' customer',
#  ' inquiries',
#  ',',
#  ' fast',
#  ' language',
#  ' models',
#  ' can',
#  ' improve',
#  ' customer',
#  ' satisfaction',
#  ' and',
#  ' reduce',
#  ' the',
#  ' workload',
#  ' of',
#  ' customer',
#  ' support',
#  ' teams',
#  '.\n',
#  '10',
#  '.',
#  ' **',
#  'Compet',
#  'itive',
#  ' advantage',
#  '**:',
#  ' Organizations',
#  ' that',
#  ' adopt',
#  ' fast',
#  ' language',
#  ' models',
#  ' can',
#  ' gain',
#  ' a',
#  ' competitive',
#  ' advantage',
#  ' in',
#  ' their',
#  ' respective',
#  ' industries',
#  ',',
#  ' as',
#  ' they',
#  ' can',
#  ' respond',
#  ' quickly',
#  ' to',
#  ' market',
#  ' trends',
#  ' and',
#  ' customer',
#  ' needs',
#  '.\n\n',
#  'In',
#  ' summary',
#  ',',
#  ' fast',
#  ' language',
#  ' models',
#  ' are',
#  ' important',
#  ' because',
#  ' they',
#  ' enable',
#  ' real',
#  '-time',
#  ' text',
#  ' processing',
#  ',',
#  ' improve',
#  ' user',
#  ' experience',
#  ',',
#  ' enhance',
#  ' decision',
#  '-making',
#  ',',
#  ' and',
#  ' reduce',
#  ' costs',
#  '.',
#  ' They',
#  ' are',
#  ' a',
#  ' critical',
#  ' component',
#  ' in',
#  ' the',
#  ' development',
#  ' of',
#  ' AI',
#  ' and',
#  ' N',
#  'LP',
#  ' technologies',
#  ',',
#  ' and',
#  ' their',
#  ' advancements',
#  ' can',
#  ' have',
#  ' a',
#  ' significant',
#  ' impact',
#  ' on',
#  ' various',
#  ' industries',
#  ' and',
#  ' applications',
#  '.',
#  None]

# %%
for chunk in stream:
    
    print(chunk.choices[0].delta.content, end="")

# %%
len(stream)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 len(stream)
#
# TypeError: object of type 'Stream' has no len()
